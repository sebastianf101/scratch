# %% [markdown]
# # Industry Accelerators - Insurance Loss Estimation Using Remote Sensing Data
#
# ## 1 - Impact Region Analysis with Remote Sensing

# %% [markdown]
# ### Contents
# - [Introduction](#intro)
# - [Libraries](#library)
# - [Query Raw Images](#queryRaw)
# - [Compute Event-Related Metrics](#metrics)
# - [Compute Event Impact Score](#impactscore)
# - [Identify Highly-Impacted Regions](#highimpact)
# - [Compute Spatial Index](#spatialindex)

# %% [markdown]
# ## Introduction <a name="intro"></a>
#
# In this notebook, we will go through the end to end process of how to derive insights on a flooding area by utilizing an example of flooding events to assist insurance claims. The idea of this notebook is to study satellite images before and after a certain event (e.g. hurricane laura), and with the help of spatiotemporal analysis and ML/AI techniques, we can get insights like which regions are affected and to what extent. Such insights provide valuable information to insurance companies for better assessing property damanages thus better deal with damage claims in a more efficient and effective way.
#
#
#
# **Sample Materials, provided under license. <br>
# Licensed Materials - Property of IBM.<br>
# © Copyright IBM Corp. 2020, 2021. All Rights Reserved.<br>
# US Government Users Restricted Rights - Use, duplication or disclosure restricted by GSA ADP Schedule Contract with IBM Corp.**
#
# **The satellite image data in this accelerator:
# 	Contains modified Copernicus Sentinel data 2020**

# %% [markdown]
# ## Prepare libraries <a name="library"></a>
#
# There are two major dependencies in this notebook:
# 1. Pyrip - a GDAL-based Raster Image Processor.
#     - Query raster data from COS in a cloud native way
#     - Merge and compute basic metrics from multiple raster layers
#     - Convert raster data to vector data.
# 2. pyst - Spatiotemporal toolkit in CP4D/WS
#     - Spatial filtering on vector data
#     - Compute convex hull from spatial points
#     - Visualize spatial objects on basemap
#     - Export spatial results to common formats like geojson, spatial dataframe, etc.
#     - Create spatial index to efficiently index spatial objects, such as finding the nearest objects from the given location.

# %% [markdown]
# Below cell installs `pyrip` library and its dependency `gdal` and imports the libraries that we will use throughout the notebook.

# %%
#%%capture
! conda install -c conda-forge gdal==3.3.2
! pip install pyrip
! ln -s /usr/lib64/libnsl.so.2 /home/spark/shared/conda/envs/python/lib/libnsl.so.1
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/spark/shared/conda/envs/python
#
#   added / updated specs:
#     - gdal==3.3.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boost-cpp-1.74.0           |       h312852a_4        16.3 MB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     c-ares-1.18.1              |       h7f98852_0         113 KB  conda-forge
#     ca-certificates-2022.6.15  |       ha878542_0         149 KB  conda-forge
#     cairo-1.16.0               |    h6cf1ce9_1008         1.5 MB  conda-forge
#     certifi-2022.6.15          |   py39hf3d152e_0         155 KB  conda-forge
#     cfitsio-3.470              |       hb418390_7         1.3 MB  conda-forge
#     curl-7.79.1                |       h2574ce0_1         153 KB  conda-forge
#     expat-2.4.8                |       h27087fc_0         187 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       hab24e00_0         1.9 MB  conda-forge
#     fontconfig-2.14.0          |       h8e229c2_0         305 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freetype-2.10.4            |       h0708190_1         890 KB  conda-forge
#     freexl-1.0.6               |       h7f98852_0          48 KB  conda-forge
#     gdal-3.3.2                 |   py39h218ed2d_4         1.9 MB  conda-forge
#     geos-3.9.1                 |       h9c3ff4c_2         1.1 MB  conda-forge
#     geotiff-1.7.0              |       hcfb7246_3         298 KB  conda-forge
#     gettext-0.19.8.1           |    h0b5b191_1005         3.6 MB  conda-forge
#     giflib-5.2.1               |       h36c2ea0_2          77 KB  conda-forge
#     hdf4-4.2.15                |       h10796ff_3         950 KB  conda-forge
#     hdf5-1.12.1                |nompi_h2750804_100         3.5 MB  conda-forge
#     icu-68.2                   |       h9c3ff4c_0        13.1 MB  conda-forge
#     jbig-2.1                   |    h7f98852_2003          43 KB  conda-forge
#     jpeg-9e                    |       h166bdaf_1         268 KB  conda-forge
#     json-c-0.15                |       h98cffda_0         274 KB  conda-forge
#     kealib-1.4.14              |       h87e4c3c_3         186 KB  conda-forge
#     keyutils-1.6.1             |       h166bdaf_0         115 KB  conda-forge
#     krb5-1.19.3                |       h3790be6_0         1.4 MB  conda-forge
#     lcms2-2.12                 |       hddcbb42_0         443 KB  conda-forge
#     lerc-2.2.1                 |       h9c3ff4c_0         213 KB  conda-forge
#     libblas-3.9.0              |15_linux64_openblas          12 KB  conda-forge
#     libcblas-3.9.0             |15_linux64_openblas          12 KB  conda-forge
#     libcurl-7.79.1             |       h2574ce0_1         335 KB  conda-forge
#     libdap4-3.20.6             |       hd7c4107_2        11.3 MB  conda-forge
#     libdeflate-1.7             |       h7f98852_5          67 KB  conda-forge
#     libedit-3.1.20191231       |       he28a2e2_2         121 KB  conda-forge
#     libev-4.33                 |       h516909a_1         104 KB  conda-forge
#     libgdal-3.3.2              |       h9c9eb65_4        13.1 MB  conda-forge
#     libgfortran-ng-12.1.0      |      h69a702a_16          23 KB  conda-forge
#     libgfortran5-12.1.0        |      hdcd56e2_16         1.8 MB  conda-forge
#     libglib-2.68.4             |       h3e27bee_0         3.0 MB  conda-forge
#     libiconv-1.16              |       h516909a_0         1.4 MB  conda-forge
#     libkml-1.3.0               |    h238a007_1014         591 KB  conda-forge
#     liblapack-3.9.0            |15_linux64_openblas          12 KB  conda-forge
#     libnetcdf-4.8.1            |nompi_hb3fd0d9_101         1.5 MB  conda-forge
#     libnghttp2-1.43.0          |       h812cca2_1         790 KB  conda-forge
#     libnsl-2.0.0               |       h7f98852_0          31 KB  conda-forge
#     libopenblas-0.3.20         |pthreads_h78a6416_0        10.1 MB  conda-forge
#     libpng-1.6.37              |       h21135ba_2         306 KB  conda-forge
#     libpq-13.3                 |       hd57d9b9_0         2.7 MB  conda-forge
#     librttopo-1.1.0            |       h1185371_6         235 KB  conda-forge
#     libspatialite-5.0.1        |       h8796b1e_9         4.4 MB  conda-forge
#     libssh2-1.10.0             |       ha56f1ee_2         233 KB  conda-forge
#     libtiff-4.3.0              |       hf544144_1         668 KB  conda-forge
#     libuuid-2.32.1             |    h7f98852_1000          28 KB  conda-forge
#     libwebp-base-1.2.2         |       h7f98852_1         824 KB  conda-forge
#     libxcb-1.13                |    h7f98852_1004         391 KB  conda-forge
#     libxml2-2.9.12             |       h72842e0_0         772 KB  conda-forge
#     libzip-1.8.0               |       h4de3113_1         126 KB  conda-forge
#     lz4-c-1.9.3                |       h9c3ff4c_1         179 KB  conda-forge
#     numpy-1.22.3               |   py39hc58783e_2         6.8 MB  conda-forge
#     openjpeg-2.4.0             |       hb52868f_1         444 KB  conda-forge
#     openssl-1.1.1o             |       h166bdaf_0         2.1 MB  conda-forge
#     pcre-8.45                  |       h9c3ff4c_0         253 KB  conda-forge
#     pixman-0.40.0              |       h36c2ea0_0         627 KB  conda-forge
#     poppler-21.09.0            |       h0e1ea10_2        16.8 MB  conda-forge
#     poppler-data-0.4.11        |       hd8ed1ab_0         3.6 MB  conda-forge
#     postgresql-13.3            |       h2510834_0         5.3 MB  conda-forge
#     proj-8.1.1                 |       h277dcde_2         2.9 MB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     tiledb-2.3.4               |       he87e0bf_0         4.1 MB  conda-forge
#     tzcode-2022a               |       h166bdaf_0          69 KB  conda-forge
#     xerces-c-3.2.3             |       h9d8b166_3         1.8 MB  conda-forge
#     xorg-kbproto-1.0.7         |    h7f98852_1002          27 KB  conda-forge
#     xorg-libice-1.0.10         |       h7f98852_0          58 KB  conda-forge
#     xorg-libsm-1.2.3           |    hd9c2040_1000          26 KB  conda-forge
#     xorg-libx11-1.7.2          |       h7f98852_0         941 KB  conda-forge
#     xorg-libxau-1.0.9          |       h7f98852_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     xorg-libxext-1.3.4         |       h7f98852_1          54 KB  conda-forge
#     xorg-libxrender-0.9.10     |    h7f98852_1003          32 KB  conda-forge
#     xorg-renderproto-0.11.1    |    h7f98852_1002           9 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h7f98852_1002          28 KB  conda-forge
#     xorg-xproto-7.0.31         |    h7f98852_1007          73 KB  conda-forge
#     zstd-1.5.0                 |       ha95c52a_0         490 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       153.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   boost-cpp          conda-forge/linux-64::boost-cpp-1.74.0-h312852a_4
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   c-ares             conda-forge/linux-64::c-ares-1.18.1-h7f98852_0
#   cairo              conda-forge/linux-64::cairo-1.16.0-h6cf1ce9_1008
#   cfitsio            conda-forge/linux-64::cfitsio-3.470-hb418390_7
#   curl               conda-forge/linux-64::curl-7.79.1-h2574ce0_1
#   expat              conda-forge/linux-64::expat-2.4.8-h27087fc_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-hab24e00_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.14.0-h8e229c2_0
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   freexl             conda-forge/linux-64::freexl-1.0.6-h7f98852_0
#   gdal               conda-forge/linux-64::gdal-3.3.2-py39h218ed2d_4
#   geos               conda-forge/linux-64::geos-3.9.1-h9c3ff4c_2
#   geotiff            conda-forge/linux-64::geotiff-1.7.0-hcfb7246_3
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-h0b5b191_1005
#   giflib             conda-forge/linux-64::giflib-5.2.1-h36c2ea0_2
#   hdf4               conda-forge/linux-64::hdf4-4.2.15-h10796ff_3
#   hdf5               conda-forge/linux-64::hdf5-1.12.1-nompi_h2750804_100
#   icu                conda-forge/linux-64::icu-68.2-h9c3ff4c_0
#   jbig               conda-forge/linux-64::jbig-2.1-h7f98852_2003
#   jpeg               conda-forge/linux-64::jpeg-9e-h166bdaf_1
#   json-c             conda-forge/linux-64::json-c-0.15-h98cffda_0
#   kealib             conda-forge/linux-64::kealib-1.4.14-h87e4c3c_3
#   keyutils           conda-forge/linux-64::keyutils-1.6.1-h166bdaf_0
#   krb5               conda-forge/linux-64::krb5-1.19.3-h3790be6_0
#   lcms2              conda-forge/linux-64::lcms2-2.12-hddcbb42_0
#   lerc               conda-forge/linux-64::lerc-2.2.1-h9c3ff4c_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-15_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-15_linux64_openblas
#   libcurl            conda-forge/linux-64::libcurl-7.79.1-h2574ce0_1
#   libdap4            conda-forge/linux-64::libdap4-3.20.6-hd7c4107_2
#   libdeflate         conda-forge/linux-64::libdeflate-1.7-h7f98852_5
#   libedit            conda-forge/linux-64::libedit-3.1.20191231-he28a2e2_2
#   libev              conda-forge/linux-64::libev-4.33-h516909a_1
#   libgdal            conda-forge/linux-64::libgdal-3.3.2-h9c9eb65_4
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-12.1.0-h69a702a_16
#   libgfortran5       conda-forge/linux-64::libgfortran5-12.1.0-hdcd56e2_16
#   libglib            conda-forge/linux-64::libglib-2.68.4-h3e27bee_0
#   libiconv           conda-forge/linux-64::libiconv-1.16-h516909a_0
#   libkml             conda-forge/linux-64::libkml-1.3.0-h238a007_1014
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-15_linux64_openblas
#   libnetcdf          conda-forge/linux-64::libnetcdf-4.8.1-nompi_hb3fd0d9_101
#   libnghttp2         conda-forge/linux-64::libnghttp2-1.43.0-h812cca2_1
#   libnsl             conda-forge/linux-64::libnsl-2.0.0-h7f98852_0
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.20-pthreads_h78a6416_0
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libpq              conda-forge/linux-64::libpq-13.3-hd57d9b9_0
#   librttopo          conda-forge/linux-64::librttopo-1.1.0-h1185371_6
#   libspatialite      conda-forge/linux-64::libspatialite-5.0.1-h8796b1e_9
#   libssh2            conda-forge/linux-64::libssh2-1.10.0-ha56f1ee_2
#   libtiff            conda-forge/linux-64::libtiff-4.3.0-hf544144_1
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h7f98852_1000
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.2.2-h7f98852_1
#   libxcb             conda-forge/linux-64::libxcb-1.13-h7f98852_1004
#   libxml2            conda-forge/linux-64::libxml2-2.9.12-h72842e0_0
#   libzip             conda-forge/linux-64::libzip-1.8.0-h4de3113_1
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.3-h9c3ff4c_1
#   numpy              conda-forge/linux-64::numpy-1.22.3-py39hc58783e_2
#   openjpeg           conda-forge/linux-64::openjpeg-2.4.0-hb52868f_1
#   pcre               conda-forge/linux-64::pcre-8.45-h9c3ff4c_0
#   pixman             conda-forge/linux-64::pixman-0.40.0-h36c2ea0_0
#   poppler            conda-forge/linux-64::poppler-21.09.0-h0e1ea10_2
#   poppler-data       conda-forge/noarch::poppler-data-0.4.11-hd8ed1ab_0
#   postgresql         conda-forge/linux-64::postgresql-13.3-h2510834_0
#   proj               conda-forge/linux-64::proj-8.1.1-h277dcde_2
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   python_abi         conda-forge/linux-64::python_abi-3.9-2_cp39
#   tiledb             conda-forge/linux-64::tiledb-2.3.4-he87e0bf_0
#   tzcode             conda-forge/linux-64::tzcode-2022a-h166bdaf_0
#   xerces-c           conda-forge/linux-64::xerces-c-3.2.3-h9d8b166_3
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.0.10-h7f98852_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.3-hd9c2040_1000
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.7.2-h7f98852_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h7f98852_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h7f98852_1
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h7f98852_1003
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h7f98852_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h7f98852_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#   zstd               conda-forge/linux-64::zstd-1.5.0-ha95c52a_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.4.26-~ --> conda-forge::ca-certificates-2022.6.15-ha878542_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main::certifi-2022.6.15-py39h06a~ --> conda-forge::certifi-2022.6.15-py39hf3d152e_0
#   openssl              pkgs/main::openssl-1.1.1p-h5eee18b_0 --> conda-forge::openssl-1.1.1o-h166bdaf_0
#
#
#
# Downloading and Extracting Packages
# fonts-conda-ecosyste | 4 KB      | ##################################### | 100%
# lcms2-2.12           | 443 KB    | ##################################### | 100%
# libdap4-3.20.6       | 11.3 MB   | ##################################### | 100%
# libtiff-4.3.0        | 668 KB    | ##################################### | 100%
# kealib-1.4.14        | 186 KB    | ##################################### | 100%
# c-ares-1.18.1        | 113 KB    | ##################################### | 100%
# libev-4.33           | 104 KB    | ##################################### | 100%
# font-ttf-inconsolata | 94 KB     | ##################################### | 100%
# ca-certificates-2022 | 149 KB    | ##################################### | 100%
# expat-2.4.8          | 187 KB    | ##################################### | 100%
# fontconfig-2.14.0    | 305 KB    | ##################################### | 100%
# libkml-1.3.0         | 591 KB    | ##################################### | 100%
# libblas-3.9.0        | 12 KB     | ##################################### | 100%
# openjpeg-2.4.0       | 444 KB    | ##################################### | 100%
# json-c-0.15          | 274 KB    | ##################################### | 100%
# curl-7.79.1          | 153 KB    | ##################################### | 100%
# libedit-3.1.20191231 | 121 KB    | ##################################### | 100%
# libnsl-2.0.0         | 31 KB     | ##################################### | 100%
# tiledb-2.3.4         | 4.1 MB    | ##################################### | 100%
# xorg-xproto-7.0.31   | 73 KB     | ##################################### | 100%
# freetype-2.10.4      | 890 KB    | ##################################### | 100%
# fonts-conda-forge-1  | 4 KB      | ##################################### | 100%
# libgdal-3.3.2        | 13.1 MB   | ##################################### | 100%
# cairo-1.16.0         | 1.5 MB    | ##################################### | 100%
# libgfortran5-12.1.0  | 1.8 MB    | ##################################### | 100%
# boost-cpp-1.74.0     | 16.3 MB   | ##################################### | 100%
# xorg-libxext-1.3.4   | 54 KB     | ##################################### | 100%
# tzcode-2022a         | 69 KB     | ##################################### | 100%
# krb5-1.19.3          | 1.4 MB    | ##################################### | 100%
# libnetcdf-4.8.1      | 1.5 MB    | ##################################### | 100%
# giflib-5.2.1         | 77 KB     | ##################################### | 100%
# openssl-1.1.1o       | 2.1 MB    | ##################################### | 100%
# xorg-libice-1.0.10   | 58 KB     | ##################################### | 100%
# libglib-2.68.4       | 3.0 MB    | ##################################### | 100%
# bzip2-1.0.8          | 484 KB    | ##################################### | 100%
# libssh2-1.10.0       | 233 KB    | ##################################### | 100%
# cfitsio-3.470        | 1.3 MB    | ##################################### | 100%
# xorg-xextproto-7.3.0 | 28 KB     | ##################################### | 100%
# libopenblas-0.3.20   | 10.1 MB   | ##################################### | 100%
# libiconv-1.16        | 1.4 MB    | ##################################### | 100%
# xorg-libxau-1.0.9    | 13 KB     | ##################################### | 100%
# libcblas-3.9.0       | 12 KB     | ##################################### | 100%
# libpng-1.6.37        | 306 KB    | ##################################### | 100%
# libgfortran-ng-12.1. | 23 KB     | ##################################### | 100%
# zstd-1.5.0           | 490 KB    | ##################################### | 100%
# liblapack-3.9.0      | 12 KB     | ##################################### | 100%
# libwebp-base-1.2.2   | 824 KB    | ##################################### | 100%
# icu-68.2             | 13.1 MB   | ##################################### | 100%
# jpeg-9e              | 268 KB    | ##################################### | 100%
# xorg-libsm-1.2.3     | 26 KB     | ##################################### | 100%
# hdf4-4.2.15          | 950 KB    | ##################################### | 100%
# libxcb-1.13          | 391 KB    | ##################################### | 100%
# xorg-libxrender-0.9. | 32 KB     | ##################################### | 100%
# libcurl-7.79.1       | 335 KB    | ##################################### | 100%
# librttopo-1.1.0      | 235 KB    | ##################################### | 100%
# keyutils-1.6.1       | 115 KB    | ##################################### | 100%
# freexl-1.0.6         | 48 KB     | ##################################### | 100%
# xorg-libxdmcp-1.1.3  | 19 KB     | ##################################### | 100%
# lerc-2.2.1           | 213 KB    | ##################################### | 100%
# xerces-c-3.2.3       | 1.8 MB    | ##################################### | 100%
# libpq-13.3           | 2.7 MB    | ##################################### | 100%
# proj-8.1.1           | 2.9 MB    | ##################################### | 100%
# libxml2-2.9.12       | 772 KB    | ##################################### | 100%
# pixman-0.40.0        | 627 KB    | ##################################### | 100%
# libdeflate-1.7       | 67 KB     | ##################################### | 100%
# xorg-renderproto-0.1 | 9 KB      | ##################################### | 100%
# font-ttf-ubuntu-0.83 | 1.9 MB    | ##################################### | 100%
# xorg-kbproto-1.0.7   | 27 KB     | ##################################### | 100%
# pthread-stubs-0.4    | 5 KB      | ##################################### | 100%
# certifi-2022.6.15    | 155 KB    | ##################################### | 100%
# pcre-8.45            | 253 KB    | ##################################### | 100%
# libnghttp2-1.43.0    | 790 KB    | ##################################### | 100%
# gdal-3.3.2           | 1.9 MB    | ##################################### | 100%
# geos-3.9.1           | 1.1 MB    | ##################################### | 100%
# lz4-c-1.9.3          | 179 KB    | ##################################### | 100%
# numpy-1.22.3         | 6.8 MB    | ##################################### | 100%
# gettext-0.19.8.1     | 3.6 MB    | ##################################### | 100%
# jbig-2.1             | 43 KB     | ##################################### | 100%
# poppler-21.09.0      | 16.8 MB   | ##################################### | 100%
# font-ttf-dejavu-sans | 388 KB    | ##################################### | 100%
# libuuid-2.32.1       | 28 KB     | ##################################### | 100%
# font-ttf-source-code | 684 KB    | ##################################### | 100%
# postgresql-13.3      | 5.3 MB    | ##################################### | 100%
# libzip-1.8.0         | 126 KB    | ##################################### | 100%
# geotiff-1.7.0        | 298 KB    | ##################################### | 100%
# libspatialite-5.0.1  | 4.4 MB    | ##################################### | 100%
# xorg-libx11-1.7.2    | 941 KB    | ##################################### | 100%
# hdf5-1.12.1          | 3.5 MB    | ##################################### | 100%
# poppler-data-0.4.11  | 3.6 MB    | ##################################### | 100%
# python_abi-3.9       | 4 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting pyrip
#   Downloading pyrip-1.5.9-py3-none-any.whl (17 kB)
# Collecting shapely
#   Downloading Shapely-1.8.2-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 1.7 MB/s eta 0:00:01
# Collecting pyproj
#   Downloading pyproj-3.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 67.6 MB/s eta 0:00:01
# Collecting rasterio
#   Downloading rasterio-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.6 MB)
#      |████████████████████████████████| 20.6 MB 70.8 MB/s eta 0:00:01
# Requirement already satisfied: numpy in ./conda/envs/python/lib/python3.9/site-packages (from pyrip) (1.22.3)
# Requirement already satisfied: pandas in /opt/ibm/conda/miniconda3.9/lib/python3.9/site-packages (from pyrip) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/ibm/conda/miniconda3.9/lib/python3.9/site-packages (from pandas->pyrip) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/ibm/conda/miniconda3.9/lib/python3.9/site-packages (from pandas->pyrip) (2021.3)
# Requirement already satisfied: six>=1.5 in /opt/ibm/conda/miniconda3.9/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->pyrip) (1.15.0)
# Requirement already satisfied: certifi in ./conda/envs/python/lib/python3.9/site-packages (from pyproj->pyrip) (2022.6.15)
# Requirement already satisfied: setuptools in /opt/ibm/conda/miniconda3.9/lib/python3.9/site-packages (from rasterio->pyrip) (58.0.4)
# Requirement already satisfied: click>=4.0 in /opt/ibm/conda/miniconda3.9/lib/python3.9/site-packages (from rasterio->pyrip) (8.0.3)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: attrs in /opt/ibm/conda/miniconda3.9/lib/python3.9/site-packages (from rasterio->pyrip) (21.2.0)
# Collecting affine
#   Downloading affine-2.3.1-py2.py3-none-any.whl (16 kB)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: pyparsing>=2.1.6 in /opt/ibm/conda/miniconda3.9/lib/python3.9/site-packages (from snuggs>=1.4.1->rasterio->pyrip) (3.0.4)
# Installing collected packages: snuggs, cligj, click-plugins, affine, shapely, rasterio, pyproj, pyrip
# Successfully installed affine-2.3.1 click-plugins-1.1.1 cligj-0.7.2 pyproj-3.3.1 pyrip-1.5.9 rasterio-1.3.0 shapely-1.8.2 snuggs-1.4.7

# %%
# %%capture
! conda install -c conda-forge gdal
! pip install pyrip
! ln -s /usr/lib64/libnsl.so.2 /home/spark/shared/conda/envs/python/lib/libnsl.so.1

# %%
import os
libs = os.environ['LD_LIBRARY_PATH']
# %env LD_LIBRARY_PATH=$libs:/home/spark/shared/conda/envs/python/lib/

# %matplotlib inline

import datetime
import branca

from pyrip.cog import query_polygon
from pyrip.image import get_shape
from pyrip.transform import tif_to_numpy, tif_to_df
from pyrip.plot import plot
from pyrip.calc import calculate

from pyst import STContext
stc = STContext(spark.sparkContext._gateway)

from sklearn.cluster import DBSCAN
import numpy as np

import pandas as pd
# Create a project object so we can read and write to project asset
from project_lib import Project
project = Project.access()
# Out:
# env: LD_LIBRARY_PATH=/opt/ibm/connectors/dsdriver/dsdriver/lib:/opt/ibm/connectors/others-db-drivers/oracle/lib:/opt/ibm/jdk/jre/lib/architecture/server:/opt/ibm/jdk/jre/lib/architecture/:/usr/local/lib:/lib64:/home/spark/shared/conda/envs/python/lib/

# %% [markdown]
# ## Step 1: Query Raw Images  <a name="queryRaw"></a>
#
# This section provides a template of querying raw data from cloud in an optimized and generalizable way, as raw data is typically in large volume and sits in cloud.
# In this accelerator, we query images for the area of Cameron, Louisiana, before and after hurricane Laura.
#
# **Since we already generated the output of this step and stored in data assets you can skip running this section and start with step 2 directly. If the user wants to analyze a different region for different period of time then please include below inputs and run the cells.**
#
# The first step of analyzing remote sensing data is to query (i.e. pull) the data of interest. The volume of remote sensing can be extremely large, so being able to query the exact data you need (e.g. pull a small neighborhood during couple days' period from 10 years global data) in a cost-efficient and time-efficient way is crucial. We utilize a cloud native way by implementing cloud-optimized raster data on native cloud storage, which is extremely fast and cost-efficient.
#
#
# We can query arbitrary region with our cloud-optimized query functions:
# - `query`: query a bbox
# - `query_radius`: query a circle (point-with-radius)
# - `query_polygon`: query an arbitrary polygon in wkt format

# %% [markdown]
# 1. Specify credentials for COS bucket that stores the remote sensing data

# %%
access_key_id = 'xxx'
secret_access_key = 'xxx'
endpoint_url = 'https://s3.us-south.cloud-object-storage.appdomain.cloud'
endpoint = endpoint_url.replace('https://', '')

# %% [markdown]
# 2. Specify area of interest, here we feed the polygon of region of interest.

# %%
cameron_polygon = 'POLYGON((-93.34231356979647 29.801644120752755,-93.32600573898593 29.79724972298948,-93.32608192997783 29.79639943818124,-93.32312077122539 29.794034556357637,-93.32202497088649 29.79096167328499,-93.3270889815066 29.784630024109077,-93.32657399737575 29.779415424066013,-93.33790364825465 29.779415424066013,-93.34108813699372 29.77461816082034,-93.34177478250153 29.76437391510573,-93.29300322900527 29.776909954345403,-93.23353082746084 29.780434142575885,-93.23387415021475 29.797268702758736,-93.34231356979647 29.801644120752755))'

# %% [markdown]
# 3. Specify local file names, in this case, we will download two bands (B03 for band Green and B08 for band Near-Infrared) before and after the event, and compute a derived layer ([NDWI](https://en.wikipedia.org/wiki/Normalized_difference_water_index)) before and the event.

# %%
b03_before = 'b03_before.tif'
b03_after = 'b03_after.tif'
b08_before = 'b08_before.tif'
b08_after = 'b08_after.tif'
ndwi_before = 'ndwi_before.tif'
ndwi_after = 'ndwi_after.tif'
ndwi_change = 'ndwi_change.tif'

# %% [markdown]
# 4. Run cloud native query to retrieve remote sensing data only for the area of interest.
# **This is where the cloud-native optimization come into place, here we query a small sample of file from underlying tens of TBs files, and we achieve sub-second performance per query. Uncomment the cell to run.**

# %%
# query_polygon('cos-url-here', b03_before, cameron_polygon, access_key_id=acs_key_id, secret_access_key=scrt_acs_key, endpoint=endpoint)
# query_polygon('cos-url-here', b03_after, cameron_polygon, access_key_id=acs_key_id, secret_access_key=scrt_acs_key, endpoint=endpoint)
# query_polygon('cos-url-here', b08_before, cameron_polygon, access_key_id=acs_key_id, secret_access_key=scrt_acs_key, endpoint=endpoint)
# query_polygon('cos-url-here', b08_after, cameron_polygon, access_key_id=acs_key_id, secret_access_key=scrt_acs_key, endpoint=endpoint)

# %% [markdown]
# ## Step 2: Compute Event-Related Metrics from Raw Images, Before and After Event <a name="metrics"></a>
#
# The second step is to derive some metrics from raw images.
#
# Once we pulled the raw images, we are interested in computing various topic-related metrics. You can use our `calculate(inputs, output, lambda_fn)` to easily apply any lambda function you need to your input images.
#
# In this case, we are interested in identifying flooding areas in Cameron due to the hurricane Laura. Therefore, we compute NDWI (Normalized Difference Water Index) layer from raw images, as flooding area after the hurricane will become watery with a higher NDWI value.
#
# The NDWI is defined by: `(Green - NIR)` / `(Green + NIR)`, and we apply this formula to both before-event images and after-event images:
#
# *Note that you can apply any formula here that is numpy-evaluable, so this function give you the power to process the images in all sorts of lambda expression you need*

# %%
# Read queried raw data. 
# This is the output from previous step 1, and we are providing this output with the demo so you don't need to setup COS and upload your own data.
b03_before = '/project_data/data_asset/b03_before.tif'
b03_after = '/project_data/data_asset/b03_after.tif'
b08_before = '/project_data/data_asset/b08_before.tif'
b08_after = '/project_data/data_asset/b08_after.tif'

# specify names of generated files
ndwi_before = 'ndwi_before.tif'
ndwi_after = 'ndwi_after.tif'
ndwi_change = 'ndwi_change.tif'

# %%
calculate([b03_before, b08_before], ndwi_before, '(A.astype("float32")-B.astype("float32"))/(A.astype("float32")+B.astype("float32"))', dtype='Float32')
calculate([b03_after, b08_after], ndwi_after, '(A.astype("float32")-B.astype("float32"))/(A.astype("float32")+B.astype("float32"))', dtype='Float32')
# Out:
# 'ndwi_after.tif'

# %%
plot(ndwi_before)

# %%
plot(ndwi_after)

# %% [markdown]
# ## Step 3: Compute Event Impact Score <a name="impactscore"></a>
#
# Now let's continue with some metrics computation.
#
# In this case, our score is defined by `water_index_after_event` - `water_index_before_event`, i.e. change of water index after the hurricane, which is only computed on areas that have low water index before the event and high water index after the event.
#
# Similar to the previous step, we leverage the same function `calculate` to apply our lambda expression:

# %%
calculate([ndwi_before, ndwi_after], ndwi_change, '(B-A)*logical_and(A<0, B>0.1)')
# Out:
# 'ndwi_change.tif'

# %% [markdown]
# This image is a grey-scaled image that captures ndwi changes. Brighter colors indicate higher changes of water index, which further indicate flooding happened. As we could see, the brighter colors form several clusters which are actually the regions that got flooded due to hurricane.

# %%
plot(ndwi_change)

# %% [markdown]
# ## Step 4: Identify Highly-Impacted Regions with Scores <a name="highimpact"></a>

# %% [markdown]
# ### Step 4.1: Convert Scoring Result from Raster Image to Vector Data
#
# So far, we have done our computations and scorings on raster data. However, such raster format is not analytical-ready. We want to have it in vector format (e.g. pandas dataframe and numpy array) which is better for further ML/AI analysis. Thus we convert the raster result to vector form, by converting it to a pandas dataframe and preserving regions that we are interested in (i.e. regions with change in water index)

# %%
df = tif_to_df(ndwi_change)
df = df[df['value']>0]
df.head(3)
# Out:
#            lat        lon     value
# 147  29.801662 -93.327965  0.642590
# 148  29.801662 -93.327868  0.622829
# 269  29.801662 -93.316085  0.752158

# %% [markdown]
# ### Step 4.2: Spatial Filtering with Waton Studio Spatiotempral Toolkit
#
# The images we pulled and computed are actually the bounding box of the cameron polygon (i.e. contains more data than we want), which is unavoidable in raster form as images always have a box shape. Now we have converted it to vector form so we can apply our spatial filter to get data that precisely falls into our polygon.

# %%
cameron_polygon = 'POLYGON((-93.34231356979647 29.801644120752755,-93.32600573898593 29.79724972298948,-93.32608192997783 29.79639943818124,-93.32312077122539 29.794034556357637,-93.32202497088649 29.79096167328499,-93.3270889815066 29.784630024109077,-93.32657399737575 29.779415424066013,-93.33790364825465 29.779415424066013,-93.34108813699372 29.77461816082034,-93.34177478250153 29.76437391510573,-93.29300322900527 29.776909954345403,-93.23353082746084 29.780434142575885,-93.23387415021475 29.797268702758736,-93.34231356979647 29.801644120752755))'
cameron = stc.wkt_reader().read(cameron_polygon)
def f(lat, lon):
    return cameron.contains(stc.point(lat, lon))

df['in_cameron'] = df.apply(lambda row: f(row['lat'], row['lon']), axis=1)
df = df[df['in_cameron']]

# %% [markdown]
# ### Step 4.3: Spatial Clustering
#
# Now we have all the point locations that are highly-impacted by the flooding issue, the next step is to cluster these points to a set of clusters (i.e. regions).
#
# In this case, we leverage DBSCAN clustering Algorithm to cluster the points.

# %%
clusters = DBSCAN(eps=0.02/6371., min_samples=5, algorithm='ball_tree', metric='haversine').fit(np.radians(df[['lat', 'lon']].values))
df['cluster'] = clusters.labels_ 
df.head(5)
# Out:
#            lat        lon     value  in_cameron  cluster
# 7985  29.80098 -93.326115  0.693647        True        0
# 7986  29.80098 -93.326018  0.700475        True        0
# 7987  29.80098 -93.325920  0.735671        True        0
# 7988  29.80098 -93.325823  0.758209        True        0
# 7989  29.80098 -93.325726  0.784354        True        0

# %%
cluster_size = df.groupby('cluster').size()
min_cluster_size = 100
target_clusters = cluster_size[cluster_size >= min_cluster_size].index.tolist()
try:
    target_clusters.remove(-1)
except ValueError:
    pass

# %% [markdown]
# ### Step 4.4: Compute Convex Hull from Clusters
#
# With a set of clusters of points, we can now form the regions. We do this by computing the convex hull of each cluster.

# %%
hulls = []
props = []
for target_cluster in target_clusters:
    tmp_df = df[df['cluster']==target_cluster]
    points = []
    for row in tmp_df.itertuples():
        points.append(stc.point(row.lat, row.lon))
    hull = stc.convex_hull.compute_convex_hull(points)
    hulls.append(hull)
    props.append((tmp_df['value'].mean(), tmp_df['value'].quantile(0.1), tmp_df['value'].quantile(0.9), hull.area()))

# %% [markdown]
# ### Step 4.5: Visualize Highly-Impacted Regions
#
# We now visualize the computed regions that are highly impacted by the event. Here the darker the color, the higher the impact score.

# %%
scores = [prop[0] for prop in props]
colorscale = branca.colormap.linear.Reds_03.scale(min(scores), max(scores))
for idx, hull in enumerate(hulls):
    if idx == 0:
        m = stc.generate_map(hull, color=colorscale(scores[idx]), fill=True, popup='score: {}, min_score: {}, max_score: {}, area: {}'.format(*props[idx]))
    else:
        m = stc.generate_map(hull, m, color=colorscale(scores[idx]), fill=True, popup='score: {}, min_score: {}, max_score: {}, area: {}'.format(*props[idx]))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10f99abfcf40ced850f49ccf783cb395 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10f99abfcf40ced850f49ccf783cb395&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_10f99abfcf40ced850f49ccf783cb395 = L.map(
#                 &quot;map_10f99abfcf40ced850f49ccf783cb395&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81938357c49a25305807bc1a9898229a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_10f99abfcf40ced850f49ccf783cb395);
#
#
#             var polygon_f4282a15a67ae7cac5ac9338d6cc9074 = L.polygon(
#                 [[29.79912995445261, -93.31735082456241], [29.799227336244094, -93.31735082456241], [29.800103772367446, -93.31881155143466], [29.80020115415893, -93.31900631501763], [29.80020115415893, -93.31959060576654], [29.800006390575962, -93.32007751472396], [29.79961686341003, -93.32007751472396], [29.799324718035578, -93.3197853693495], [29.79854566370371, -93.3186167878517], [29.79854566370371, -93.31851940606022], [29.798935190869642, -93.31774035172835], [29.79912995445261, -93.31735082456241]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e84f3fff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e84f3fff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_10f99abfcf40ced850f49ccf783cb395);
#
#
#         var popup_b24e1958969bbccdf4e274a5ba7d09fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8e7f051075391aa165b5b7b430626938 = $(`&lt;div id=&quot;html_8e7f051075391aa165b5b7b430626938&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;score: 0.8005666136741638, min_score: 0.7396957516670227, max_score: 0.8601691246032714, area: 28043.65945724511&lt;/div&gt;`)[0];
#             popup_b24e1958969bbccdf4e274a5ba7d09fd.setContent(html_8e7f051075391aa165b5b7b430626938);
#
#
#         polygon_f4282a15a67ae7cac5ac9338d6cc9074.bindPopup(popup_b24e1958969bbccdf4e274a5ba7d09fd)
#         ;
#
#
#
#
#             map_10f99abfcf40ced850f49ccf783cb395.fitBounds(
#                 [[29.79854566370371, -93.32007751472396], [29.800201154480128, -93.31735082456241]],
#                 {}
#             );
#
#
#             var polygon_2534b2825c82967174cacae14b681722 = L.polygon(
#                 [[29.79513730100178, -93.23389462926089], [29.795234682793264, -93.23389462926089], [29.797182318622937, -93.23399201105237], [29.79727970041442, -93.23418677463533], [29.79727970041442, -93.23564750150759], [29.795234682793264, -93.23584226509055], [29.794942537418812, -93.23584226509055], [29.794942537418812, -93.23506321075868], [29.795039919210296, -93.23399201105237], [29.79513730100178, -93.23389462926089]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e43e33ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e43e33ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_10f99abfcf40ced850f49ccf783cb395);
#
#
#         var popup_e27eb153c5d44432e83f1cbe8482d22c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_975dc1bc2f88e2e374c1461590fa0bce = $(`&lt;div id=&quot;html_975dc1bc2f88e2e374c1461590fa0bce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;score: 0.8257400989532471, min_score: 0.7522392511367798, max_score: 0.9091104090213776, area: 44871.473829918905&lt;/div&gt;`)[0];
#             popup_e27eb153c5d44432e83f1cbe8482d22c.setContent(html_975dc1bc2f88e2e374c1461590fa0bce);
#
#
#         polygon_2534b2825c82967174cacae14b681722.bindPopup(popup_e27eb153c5d44432e83f1cbe8482d22c)
#         ;
#
#
#
#
#             map_10f99abfcf40ced850f49ccf783cb395.fitBounds(
#                 [[29.794942537418805, -93.32007751472396], [29.80020115415893, -93.23389462926089]],
#                 {}
#             );
#
#
#             var polygon_b6508f3f01db81574bd820c9e2553bcf = L.polygon(
#                 [[29.79124202934243, -93.27372378197772], [29.791339411133915, -93.27372378197772], [29.792410610840236, -93.27567141780739], [29.79250799263172, -93.2760609

# %% [markdown]
# ## Step 5. Spatial Index <a name="spatialindex"></a>
#
# Now that we have enough information about the event impact - the boundary of the impacted area along with the impact score - we can perform customer profiling by leveraging spatial index to calculate if and how much each customer's property got affected. This is the business insight we want to gain from this demo.

# %% [markdown]
# ### Step 5.1 Get Property Locations
#
# Here we read in property locations.

# %%
properties = pd.read_csv(project.get_file('Remote Sensing Input.csv'))
properties.head(3)
# Out:
#    PropertyId       lat        lon
# 0        1001  29.80098 -93.326115
# 1        1002  29.80098 -93.326018
# 2        1003  29.80098 -93.325920

# %% [markdown]
# ### Step 5.2 Create In-Memory Spatial Index for Impacted Regions
#
# We create an in-memory spatial index, and push the boundaries of all impacted areas to the index, which allows us to index any given location on if the location is within any of these impacted areas.

# %%
index = stc.tessellation_index(bbox=cameron.get_bounding_box(), tile_size=100)

# %%
for idx, hull in enumerate(hulls):
    index.put(hull, 'zone_{}-{}'.format(idx, '-'.join(map(str, props[idx]))))

# %% [markdown]
# ### Step 5.3 Index Property Locations and Augment Impact Info ①
#
# We profile each property location by augmenting whether the property is within any impacted region, along with the region id and impact score.

# %%
# Based on your application, you might want to normalize your metrics to clip your normalized score within a certain range, e.g. 0 to 1.
MIN_CHANGE_SCORE = 0.3
MAX_CHANGE_SCORE = 1.1
def norm_score(v):
    return (v - MIN_CHANGE_SCORE) / (MAX_CHANGE_SCORE - MIN_CHANGE_SCORE)

# %%
def f2(lat, lon):
    res = index.containing(stc.point(lat, lon))
    if len(res) == 0:
        return pd.Series([False, None, 0, 0, 0])
    else:
        return pd.Series([True, 
                          res[0].split('-')[0],
                          norm_score(float(res[0].split('-')[1])), 
                          norm_score(float(res[0].split('-')[2])), 
                          norm_score(float(res[0].split('-')[3]))])

# %%
properties[['within_impacted_zones', 'Impact_Zone', 'Impact_Score', 'Impact_Score_min', 'Impact_Score_max']] = properties.apply(lambda row: f2(row['lat'], row['lon']), axis=1)

# %%
properties.sort_values('Impact_Score', ascending=False).head(6)
# Out:
#       PropertyId        lat        lon  within_impacted_zones Impact_Zone  \
# 1891        2892  29.791145 -93.276937                   True      zone_2
# 1812        2813  29.791339 -93.274698                   True      zone_2
# 1835        2836  29.791242 -93.277911                   True      zone_2
# 1834        2835  29.791242 -93.278009                   True      zone_2
# 1833        2834  29.791242 -93.278106                   True      zone_2
# 1832        2833  29.791242 -93.278203                   True      zone_2
#
#       Impact_Score  Impact_Score_min  Impact_Score_max
# 1891      0.691814          0.595193          0.785853
# 1812      0.691814          0.595193          0.785853
# 1835      0.691814          0.595193          0.785853
# 1834      0.691814          0.595193          0.785853
# 1833      0.691814          0.595193          0.785853
# 1832      0.691814          0.595193          0.785853

# %% [markdown]
# ### Step 5.4 Index Property Locations and Augment Impact Info ②
#
# In the example above, we categorize each property into either impacted or non-impacted. However, for the non-impacted properties, we might be also interested in their distance from the nearest impacted region, which can help the business decide if an alarm should be raised for these customers.

# %%
def f3(lat, lon):
    res = index.nearest_neighbors_with_info(stc.point(lat, lon), 1)[0]
    return pd.Series([res[0].split('-')[0], 
                      norm_score(float(res[0].split('-')[1])), 
                      norm_score(float(res[0].split('-')[2])), 
                      norm_score(float(res[0].split('-')[3])),
                      res[2]])

# %%
properties[['Nearest_Impacted_Zone', 'Nearest_Impacted_Zone_Score', 'Nearest_Impacted_Score_min', 'Nearest_Impacted_Score_max', 'Distance_to_Nearest_Impact_Zone']] = properties.apply(lambda row: f3(row['lat'], row['lon']), axis=1)

# %%
properties.head(3)
# Out:
#    PropertyId       lat        lon  within_impacted_zones Impact_Zone  \
# 0        1001  29.80098 -93.326115                  False        None
# 1        1002  29.80098 -93.326018                  False        None
# 2        1003  29.80098 -93.325920                  False        None
#
#    Impact_Score  Impact_Score_min  Impact_Score_max Nearest_Impacted_Zone  \
# 0           0.0               0.0               0.0                zone_0
# 1           0.0               0.0               0.0                zone_0
# 2           0.0               0.0               0.0                zone_0
#
#    Nearest_Impacted_Zone_Score  Nearest_Impacted_Score_min  \
# 0                     0.625708                     0.54962
# 1                     0.625708                     0.54962
# 2                     0.625708                     0.54962
#
#    Nearest_Impacted_Score_max  Distance_to_Nearest_Impact_Zone
# 0                    0.700211                       593.220841
# 1                    0.700211                       583.974036
# 2                    0.700211                       574.733403

# %% [markdown]
# ### Step 5.4:  Save out the Result
# The above results will be saved in to the data assets using project_lib. In our next notebook `2-model-training-and-deployments`, this result will be used to predict Estimated Claim Amount on the individual properties.

# %%
project.save_data('Remote Sensing Output.csv', properties.to_csv(index=False), overwrite=True)
# Out:
# {'file_name': 'Remote Sensing Output.csv',
#  'message': 'File saved to project storage.',
#  'asset_id': '1c744c54-501f-49c8-affb-ae6e59d5625f'}
